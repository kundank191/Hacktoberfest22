# %%
import requests
import re
from bs4 import BeautifulSoup
from time import sleep
import urllib.parse

# %%
def get_new_url(phone):
    phone = phone.strip()
    phone=phone.lower()
    phone = phone.replace(" ", "-")
    phone = phone+"-price-in-india"
    return("https://www.91mobiles.com/" + phone)

# %%
phones = ['Samsung SM-M307F',
'Samsung SM-G780F',
'Xiaomi Redmi 8',
'Motorola Moto G (5) Plus',
'Asus X00TD',
'OnePlus AC2001',
'Realme RMX2002',
'Xiaomi Redmi Note 8',
'OPPO CPH1937',
'Huawei BKK-AL10',
'Nokia 8.1',
'Lenovo L38012',
'Xiaomi M2003J15SC',
'Samsung SM-M515F',
'Huawei LLD-AL20',
'Realme RMX2030',
'Samsung SM-N950F',
'Samsung SM-G985F',
'Vivo 1726',
'Realme RMX1971',
'OPPO CPH2127',
'Infinix X650C',
'Samsung SM-A750F',
'Samsung SM-J710F',
'Realme RMX2001',
'Samsung SM-M315F',
'Samsung SM-A217F',
'Samsung SM-A207F',
'Realme RMX2103',
'Xiaomi Redmi 8A Dual',
'Xiaomi Redmi Note 9 Pro',
'Samsung SM-J510FN',
'OPPO CPH1801',
'Xiaomi M2004J19PI',
'Xiaomi POCO X2',
'Xiaomi Redmi Note 9 Pro Max',
'Vivo V2025',
'Realme 6i',
'Nokia 2.2',
'Samsung SM-A315F',
'Xiaomi POCO M2 Pro',
'Huawei LLD-AL10',
'OnePlus HD1911',
'Motorola Moto G (5S) Plus',
'Samsung SM-F415F',
'Realme RMX2151',
'Realme RMX2189',
'Vivo V2029',
'Vivo 1820',
'Samsung SM-M215F',
'OnePlus HD1901',
'Realme RMX2027',
'Realme RMX2180',
'Vivo 1906',
'Realme RMX2170',
'Huawei STK-L22',
'Realme RMX2193',
'Samsung SM-A707F',
'Huawei BND-AL10',
'Huawei AUM-AL20',
'Samsung SM-M317F',
'OPPO CPH2015',
'Nokia 6.1',
'Vivo 1915',
'OPPO CPH2001',
'Samsung SM-M115F',
'0 0',
'Vivo 1935',
'Samsung SM-A605G',
'Nokia 2.3',
'Vivo 1909',
'Vivo 1920_20',
'Samsung SM-G955F',
'Vivo 1921',
'Huawei HRY-AL00Ta',
'Samsung SM-A715F',
'Nokia 5.1 Plus',
'Realme RMX1921',
'Huawei RNE-L22',
'Realme RMX2195',
'OPPO CPH2185',
'Samsung SM-M015G',
'Nokia 6.1 Plus',
'OPPO CPH2083',
'Samsung SM-A307FN',
'Samsung SM-G965F',
'Vivo V2027',
'Vivo 1920',
'Samsung SM-J610F',
'Realme RMX1925',
'Lenovo A7020a48',
'Vivo 1919',
'Xiaomi M2006C3LI',
'OPPO CPH2095',
'Samsung SM-A605F',
'Samsung SM-N770F',
'Vivo 1916',
'Asus X013DC',
'Motorola Moto E(4)',
'Samsung SM-A515F',
'Nokia 3.1 Plus',
'Lenovo K33a42',
'Xiaomi Redmi 8A',
'Nokia 7.2',
'Motorola Moto g(9)',
'OPPO CPH1945',
'Samsung SM-J250F',
'Samsung SM-G532G',
'Huawei INE-LX1',
'Samsung SM-A510F',
'Samsung SM-G988U1',
'Huawei COR-AL00',
'OPPO A37fw',
'Huawei JSN-L42',
'Realme RMX2161',
'Samsung SM-N975F',
'OPPO CPH2119',
'Realme RMX2185',
'Vivo 1938',
'Xiaomi M2004J19C',
'Huawei YAL-AL00',
'OPPO CPH2061',
'Nokia 3.2',
'Realme RMX1992',
'Vivo 1902',
'itel L5002',
'Xiaomi M2006C3MII',
'Samsung SM-M013F',
'Geotel A1',
'OnePlus IN2021',
'OPPO A33f',
'Realme RMX2061',
'Samsung SM-J210F',
'Infinix X655D',
'Samsung SM-P615',
'OPPO CPH1989',
'OnePlus IN2011',
'Motorola Moto One Macro',
'Lava Z61 2GB',
'Samsung SM-N980F',
'Samsung SM-G980F',
'Samsung SM-G965W',
'Realme RMX1931',
'Micromax Q402+ Bharat 2 Plus',
'Huawei STK-L21',
'Samsung SM-J415F',
'Samsung SM-J200G',
'Huawei PRA-AL00X',
'Samsung SM-A710F',
'Samsung SM-N986B',
'Samsung SM-C701F',
'OnePlus KB2001',
'Huawei MYA-L22',
'Samsung SM-A908B',
'Xiaomi M2007J20CI',
'Infinix X680D',
'Xiaomi M2006C3LII',
'Huawei DUB-LX1',
'OPPO A37f',
'Samsung SM-G770F',
'Vivo Y55 1603',
'Motorola moto g(8) plus',
'Infinix X682C',
'Samsung SM-M017F',
'Samsung SM-G975F',
'Motorola Moto E6s',
'Vivo 1933',
'Vivo V2022',
'Realme RMX2085',
'Samsung SM-M107F',
'Samsung SM-J710FN',
'Samsung SM-J330G',
'Samsung SM-J510GN',
'Huawei JAT-L29',
'Nokia 5.1',
'Huawei CAM-UL00',
'Nokia 7.1',
'Tecno KC1j',
'Samsung SM-A730F',
'HTC Desire',
'Samsung SM-A750GN',
'Motorola One Fusion+',
'Lenovo A7010a48',
'Motorola Moto E (4) Plus',
'Huawei HRY-AL00',
'LG LM-G850',
'Samsung SM-G965U1',
'OPPO CPH2109',
'10.or E',
'OPPO CPH1919',
'Motorola moto e(7) plus',
'Motorola moto g(6)',
'Micromax Q4311',
'Oukitel K6',
'Samsung SM-A720F',
'Tecno BB4k',
'Realme RMX2050',
'Huawei LLD-L21',
'Huawei DUK-L09',
'Infinix X626B',
'Vivo 1917',
'Samsung SM-A520F',
'Micromax Q4310',
'Infinix X690',
'Nokia 6.2',
'Asus X00LD',
'OPPO CPH2035',
'Tecno KE5',
'LeTV Le X509',
'Samsung SM-N960F',
'LG LM-X600IM',
'10.or D',
'Huawei JSN-L22',
'Huawei MHA-L29',
'Xiaomi Mi 10',
'Samsung SM-J530Y',
'OnePlus HD1903',
'Vivo 2004',
'Samsung SM-N970F',
'Lenovo Moto G (5S)',
'Samsung SM-F916B',
'Vivo V3Max',
'Lava LE9830',
'Samsung SM-G781B',
'Asus Z00LD',
'Sony H4311',
'Lenovo L28111',
'Gionee MAX',
'Tecno KE6',
'Micromax Q4204',
'LG K420',
'Lenovo ZUK Z2132',
'Infinix X655F',
'Xiaomi Redmi Note 9S',
'Xiaomi 2014818',
'Xiaomi Mi 5X',
'Xiaomi Redmi K30 5G',
'Samsung SM-A405FN',
'Lava Z51',
'Samsung SM-G975U1',
'Asus Z017DB',
'Vivo 1805',
'Samsung SM-G965U',
'Coolpad 1825',
'Samsung SM-G955U',
'X-TIGI A1 Plus',
'Micromax E483',
'Huawei HRY-LX1',
'itel L6005',
'Huawei JKM-Al00A',
'Lenovo PB-6505M',
'OPPO CPH1907',
'Lava A97 2GB',
'Huawei DUA-AL00',
'Samsung SM-G955W',
'Huawei PRA-LA1',
'Huawei BND-L21',
'Motorola MotoG3',
'Lenovo P2a42',
'LG LMX130IM',
'itel it1518',
'HTC Wildfire R70',
'Samsung SM-N910T',
'Lava Z66',
'LG LG-M320',
'Tecno KC1',
'Vivo 2006',
'Tecno CD7',
'Samsung SM-G988B',
'Huawei DUA-L22',
'LYF LS-5015',
'Realme RMX2081',
'Samsung SM-G9550',
'Infinix X650D',
'Huawei BKK-LX2',
'Tecno LC8',
'Infinix X573',
'LYF LS-4008',
'Motorola Moto g(8) power lite',
'Samsung SM-J710GN',
'Huawei TRT-LX1',
'10.or G',
'Samsung SM-G970F',
'Huawei FDR-A01L',
'Asus X00RD',
'Tecno ID3k',
'Tecno KB2J',
'Google Pixel 4a',
'Xiaomi MI 8 Lite',
'itel S41',
'Samsung SM-T385',
'Vivo 1851',
'Tecno KC3',
'Samsung SM-M307FN',
'Nokia 4.2',
'LG LM-G910',
'Huawei RNE-L21',
'Lenovo L39051',
'Sharp X1',
'Tecno KC2j',
'Samsung SM-T307U',
'Huawei WAS-LX2J',
'Motorola XT1650',
'LG X230',
'JHM X11',
'Tecno KB2',
'Huawei ATU-L31',
'itel L5503',
'Micromax N8301',
'LG LM-G710',
'Samsung SM-N976N',
'Micromax Q402',
'Tecno KB3',
'Nokia C3',
'LYF LS-5201',
'Panasonic Eluga Ray 810',
'Micromax iOne',
'Huawei PCT-AL10',
'Vodafone VFD 500',
'Huawei KIW-L22',
'Gionee P5W',
'Nokia 3.1',
'ZTE NX573J',
'ZTE NX569J',
'Samsung SM-G9650',
'Nokia 2.1',
'Micromax N8216',
'OPPO CPH2137',
'Huawei COL-AL10',
'InFocus M680',
'Tecno CD8',
'Huawei FIG-LA1',
'Huawei COL-L29',
'Infinix X626',
'Lenovo TB-7504X',
'Motorola MotoG3-TE',
'Tecno KD7',
'Tecno KD7h',
'Infinix X573B',
'Tecno IN6',
'Lenovo TB-8504X',
'OPPO F1f',
'OPPO CPH2023',
'Samsung SM-G532F',
'Tecno IA5',
'Gionee Pioneer P5L (2016)',
'Gionee F10',
'Samsung SM-N7505',
'Samsung SM-J701M',
'iVoomi Me 1+',
'Samsung SM-G975U',
'Samsung SM-G970U',
'Xiaomi Mi Note 10 Lite',
'Sony F8332',
'Samsung SM-A015F',
'Lenovo L19041',
'Huawei EVA-L19',
'Lenovo TB-8704X',
'itel L5502',
'Coolpad 3503I Mega 3',
'Tecno KC2',
'LYF LS-5002',
'Samsung SM-P610',
'Tecno LB8a',
'Infinix X650B',
'Samsung SM-A750FN',
'Infinix X652',
'Huawei NEM-L22',
'Huawei STF-AL00',
'Coolpad 1861',
'Sony E2363',
'Samsung GT-I9505',
'Intex Aqua Life III',
'OPPO CPH1613',
'Intex Aqua Twist',
'HTC Desire 828',
'LG LM-G900',
'Asus Z010D',
'Coolpad 1826-I01',
'itel L6006',
'Samsung SM-T290',
'Huawei LDN-LX2',
'Vivo V1Max',
'Huawei BKL-L09',
'Huawei FLA-LX1',
'itel L5503L',
'Micromax YU5014',
'Tecno LC7',
'Kult Gladiator',
'Lenovo TB3-730X',
'Huawei JDN2-AL00HN',
'Panasonic I7 EE',
'OPPO 1201',
'Huawei AMN-LX9',
'Micromax Q4002',
'OPPO CPH2043',
'Xolo Era 5X',
'Huawei CUN-L21',
'Gome C7 Note',
'Lava Iris X8 L',
'Micromax Q4260',
'Micromax Q452',
'Samsung SM-T295',
'Lava V2 3GB',
'Samsung SM-G781V',
'Tecno KE6j',
'Samsung SM-N950U1',
'Asus X00LDB',
'Tambo TA-3',
'Tecno TECNO IN1',
'Samsung SM-N9500',
'ZTE NX575J',
'Micromax YU5510A',
'Tecno CE7',
'OPPO CPH1879',
'OnePlus ONE A2003',
'Samsung SM-G7202',
'Micromax C2APLS',
'Yuho O2',
'Tecno ID6',
'HTC M8e',
'OnePlus KB2000',
'Samsung SM-A716B',
'Samsung SM-G986U',
'Xiaomi Mi 9 Lite',
'Lenovo P70-A',
'Infinix X652B',
'Samsung SM-G530FZ',
'Xolo Era 2X',
'itel A41 Plus',
'Xiaomi Mi Note 10',
'Infinix X682B',
'OPPO CPH1875',
'Samsung SM-F907N',
'Huawei HRY-LX2',
'Motorola Moto g(7)',
'Sony C6903',
'Panasonic Eluga I8',
'Samsung SM-N935F',
'Nokia 5.3',
'Samsung SM-G975W',
'Motorola XT1068',
'Samsung SM-G986U1',
'Samsung SM-T825',
'itel A41',
'Samsung SM-F700F',
'Huawei PIC-LX9',
'OPPO CPH1611',
'Tecno LB7',
'Vivo V2026',
'Huawei YAL-L21',
'Huawei POT-LX1AF',
'Lenovo A2016a40 B',
'Lava LF9810_2GB',
'Asus I001DE',
'Tecno KC8',
'Sony E5563',
'HTC M9 Plus',
'Samsung SM-T285YD',
'Micromax HS3',
'Infinix X660',
'Samsung SM-J320G',
'Samsung SM-J610G',
'Asus X00TDA',
'Lenovo TB-8505F',
'Samsung SM-G955U1',
'Samsung SM-T515',
'Intex Aqua Ring',
'Zee Z10',
'Panasonic Eluga Ray 800',
'Samsung SM-G903F',
'Vivo 1907_19',
'LG LM-G810',
'Panasonic Eluga Mark',
'BlackBerry BBE100-4',
'Motorola G8 Power',
'Samsung SM-G988U',
'Umidigi S2',
'Samsung SM-A115F',
'Micromax C1A',
'Sony Xperia Z1',
'Asus I01WD',
'Intex Aqua Young',
'Alcatel 5060A',
'Amosta 3G5',
'SonyEricsson C6602',
'InFocus IF9007',
'Samsung SM-T355Y',
'Huawei BKL-AL20',
'Samsung SM-A202F',
'Karbonn K9 Smart Selfie',
'OnePlus HD1910',
'Micromax C2A',
'Huawei AUM-AL29',
'Tecno BC2',
'Xiaomi M2006C3LG',
'Vivo I1928',
'Karbonn Frames S9',
'Nokia C2',
'Xiaomi Redmi Note 5A Prime',
'Huawei LND-L29',
'Samsung SM-G970U1',
'Huawei NXT-AL10',
'Samsung SM-T510',
'Xiaomi M2006C3MG',
'Panasonic ELUGA Ray 610',
'Kyocera E6560',
'Lava Pixel V2',
'Lenovo TB-X505X',
'LG LM-K510',
'Samsung SM-N976Q',
'Samsung SM-N970U',
'OnePlus IN2020',
'Karbonn Aura Sleek 4G',
'Xiaomi MI 9',
'Samsung SM-G9208',
'Comio C1 Pro',
'OnePlus IN2013',
'Samsung SM-J700H',
'Huawei HRY-LX1T',
'Samsung SM-T585',
'Samsung SM-J737T1',
'Huawei COR-L29',
'Lava Iris 88',
'Samsung SM-G920A',
'Motorola Moto G9 Play',
'OPPO CPH2059',
'Vivo 1940',
'Samsung SM-T815Y',
'ZTE Blade V0730',
'Coolpad 1825-I01',
'Samsung SM-G6000',
'Micromax Q413',
'Samsung SM-G9750',
'Vivo I1927',
'Coolpad 1821',
'Huawei RIO-L01',
'Lava LE9810',
'Lava A71',
'Samsung SM-N981B',
'Samsung SM-G935S',
'Samsung SM-T720',
'Samsung SM-N950U',
'Samsung SM-T505',
'Intex Aqua Strong 5.2',
'Lephone W7R',
'Lava Z61P',
'Google Nexus 5X',
'LG H872',
'Xiaomi M2002J9G',
'Xiaomi Mi MIX 2S',
'Lenovo A6600a40',
'Samsung SM-F707B',
'Lenovo TB-X605LC',
'Gionee E8',
'Samsung SM-J320A',
'Centric CM5001',
'Samsung SM-G981B',
'Samsung SM-T285',
'Sony G8342',
'Razer Phone 2',
'Motorola XT1686',
'Tecno itel-it1520',
'Micromax Q427',
'OnePlus HD1905',
'Huawei DLI-L42',
'Huawei BLL-L21',
'Samsung SM-T580',
'Lenovo TB-8505X',
'Samsung SM-G920AZ',
'Lenovo TB-X304L',
'OPPO CPH1851',
'Samsung SM-N960U',
'Samsung SM-J200F',
'HTC U11 Plus',
'Vivo X9i',
'LG LM-Q850',
'Samsung SM-N960W',
'OnePlus HD1900',
'Samsung SM-G570Y',
'Motorola XT1580',
'OnePlus E1005',
'Gionee S6',
'BlackBerry BBD100-1',
'Nokia 2.4',
'Motorola Moto E6 Play',
'Benco LE9920_P',
'M-tech Eros Smart',
'Samsung SM-T500',
'LYF LS-5501',
'Samsung SM-A5070',
'Lenovo K11 Power',
'Xiaomi Redmi Note 8T',
'Huawei DRA-LX5',
'Samsung SM-G977B',
'Samsung SM-N986U1',
'OPPO Reno4',
'Huawei CAM-L21',
'Coolpad Y83-I00',
'QMobile i6 Metal 2017',
'iBall Snap 4G2',
'OPPO CPH1951',
'Xolo Era 2X 3GB',
'Micromax Q372',
'Meizu 16th',
'Asus Z011D',
'Samsung SM-N9750',
'Huawei FIG-LX1',
'Lenovo K33 a48',
'Intex Aqua Power HD',
'HTC M9',
'Samsung SM-A426B',
'InFocus IF9031',
'Infinix X687',
'Lava P7plus',
'InFocus M260',
'Samsung SM-C9008',
'Motorola Moto G Stylus',
'Xiaomi 2014817',
'Vivo 1937',
'Mobell Tab 8',
'Micromax Q409',
'CAT S61',
'Asus X00ADC',
'Samsung SM-A217N',
'LG LM-F100',
'Huawei PCT-L29',
'LG LG-K220',
'Asus I003DD',
'itel P41',
'Micromax Q394',
'Infinix X680',
'Infinix X624',
'Lenovo YT3-X90F',
'Lava Z92',
'TP-Link Neffos C7',
'Intex Cloud Jewel',
'Samsung SM-N986U',
'OPPO Ax5s',
'Samsung SM-G955N',
'HTC U11 life',
'Ampe A77',
'LG LM-X210',
'LG LM-Q730',
'itel W6004',
'Infinix X650',
'Samsung SM-A115U1',
'Samsung SM-T805',
'Intex AQUA AMAZE+']

# %%
price = "NA"
for p in phones:
    new_url = get_new_url(p)
    thepage = requests.get(new_url)
    soup = BeautifulSoup(thepage.text, "html.parser")
    
    for div in soup.find_all('div', {'class': 'price_div'}):
        try:
            price = str(div.find('span', {'class': 'big_prc','itemprop':'price'}).getText()).strip()
        except:
            price = "NA"
        
    print(p+" -- "+price)
    price = "NA"
# Out:
# Samsung SM-M307F -- NA
# Samsung SM-G780F -- NA
# Xiaomi Redmi 8 -- 7,999
# Motorola Moto G (5) Plus -- NA
# Asus X00TD -- NA
# OnePlus AC2001 -- NA
# Realme RMX2002 -- NA
# Xiaomi Redmi Note 8 -- 12,290
# OPPO CPH1937 -- NA
# Huawei BKK-AL10 -- NA
# Nokia 8.1 -- NA
# Lenovo L38012 -- NA
# Xiaomi M2003J15SC -- NA
# Samsung SM-M515F -- NA
# Huawei LLD-AL20 -- NA
# Realme RMX2030 -- NA
# Samsung SM-N950F -- NA
# Samsung SM-G985F -- NA
# Vivo 1726 -- NA
# Realme RMX1971 -- NA
# OPPO CPH2127 -- NA
# Infinix X650C -- NA
# Samsung SM-A750F -- NA
# Samsung SM-J710F -- NA
# Realme RMX2001 -- NA
# Samsung SM-M315F -- NA
# Samsung SM-A217F -- NA
# Samsung SM-A207F -- NA
# Realme RMX2103 -- NA
# Xiaomi Redmi 8A Dual -- 7,499
# Xiaomi Redmi Note 9 Pro -- 12,994
# Samsung SM-J510FN -- NA
# OPPO CPH1801 -- NA
# Xiaomi M2004J19PI -- NA
# Xiaomi POCO X2 -- 18,999
# Xiaomi Redmi Note 9 Pro Max -- 15,789
# Vivo V2025 -- NA
# Realme 6i -- 12,949
# Nokia 2.2 -- NA
# Samsung SM-A315F -- NA
# Xiaomi POCO M2 Pro -- 11,890
# Huawei LLD-AL10 -- NA
# OnePlus HD1911 -- NA
# Motorola Moto G (5S) Plus -- NA
# Samsung SM-F415F -- NA
# Realme RMX2151 -- NA
# Realme RMX2189 -- NA
# Vivo V2029 -- NA
# Vivo 1820 -- NA
# Samsung SM-M215F -- NA
# OnePlus HD1901 -- NA
# Realme RMX2027 -- NA
# Realme RMX2180 -- NA
# Vivo 1906 -- NA
# Realme RMX2170 -- NA
# Huawei STK-L22 -- NA
# Realme RMX2193 -- NA
# Samsung SM-A707F -- NA
# Huawei BND-AL10 -- NA
# Huawei AUM-AL20 -- NA
# Samsung SM-M317F -- NA
# OPPO CPH2015 -- NA
# Nokia 6.1 -- NA
# Vivo 1915 -- NA
# OPPO CPH2001 -- NA
# Samsung SM-M115F -- NA
# 0 0 -- NA
# Vivo 1935 -- NA
# Samsung SM-A605G -- NA
# Nokia 2.3 -- NA
# Vivo 1909 -- NA
# Vivo 1920_20 -- NA
# Samsung SM-G955F -- NA
# Vivo 1921 -- NA
# Huawei HRY-AL00Ta -- NA
# Samsung SM-A715F -- NA
# Nokia 5.1 Plus -- NA
# Realme RMX1921 -- NA
# Huawei RNE-L22 -- NA
# Realme RMX2195 -- NA
# OPPO CPH2185 -- NA
# Samsung SM-M015G -- NA
# Nokia 6.1 Plus -- NA
# OPPO CPH2083 -- NA
# Samsung SM-A307FN -- NA
# Samsung SM-G965F -- NA
# Vivo V2027 -- NA
# Vivo 1920 -- NA
# Samsung SM-J610F -- NA
# Realme RMX1925 -- NA
# Lenovo A7020a48 -- NA
# Vivo 1919 -- NA
# Xiaomi M2006C3LI -- NA
# OPPO CPH2095 -- NA
# Samsung SM-A605F -- NA
# Samsung SM-N770F -- NA
# Vivo 1916 -- NA
# Asus X013DC -- NA
# Motorola Moto E(4) -- NA
# Samsung SM-A515F -- NA
# Nokia 3.1 Plus -- NA
# Lenovo K33a42 -- NA
# Xiaomi Redmi 8A -- 7,999
# Nokia 7.2 -- NA
# Motorola Moto g(9) -- NA
# OPPO CPH1945 -- NA
# Samsung SM-J250F -- NA
# Samsung SM-G532G -- NA
# Huawei INE-LX1 -- NA
# Samsung SM-A510F -- NA
# Samsung SM-G988U1 -- NA
# Huawei COR-AL00 -- NA
# OPPO A37fw -- NA
# Huawei JSN-L42 -- NA
# Realme RMX2161 -- NA
# Samsung SM-N975F -- NA
# OPPO CPH2119 -- NA
# Realme RMX2185 -- NA
# Vivo 1938 -- NA
# Xiaomi M2004J19C -- NA
# Huawei YAL-AL00 -- NA
# OPPO CPH2061 -- NA
# Nokia 3.2 -- NA
# Realme RMX1992 -- NA
# Vivo 1902 -- NA
# itel L5002 -- NA
# Xiaomi M2006C3MII -- NA
# Samsung SM-M013F -- NA
# Geotel A1 -- 10,410
# OnePlus IN2021 -- NA
# OPPO A33f -- NA
# Realme RMX2061 -- NA
# Samsung SM-J210F -- NA
# Infinix X655D -- NA
# Samsung SM-P615 -- NA
# OPPO CPH1989 -- NA
# OnePlus IN2011 -- NA
# Motorola Moto One Macro -- NA
# Lava Z61 2GB -- NA
# Samsung SM-N980F -- NA
# Samsung SM-G980F -- NA
# Samsung SM-G965W -- NA
# Realme RMX1931 -- NA
# Micromax Q402+ Bharat 2 Plus -- NA
# Huawei STK-L21 -- NA
# Samsung SM-J415F -- NA
# Samsung SM-J200G -- NA
# Huawei PRA-AL00X -- NA
# Samsung SM-A710F -- NA
# Samsung SM-N986B -- NA
# Samsung SM-C701F -- NA
# OnePlus KB2001 -- NA
# Huawei MYA-L22 -- NA
# Samsung SM-A908B -- NA
# Xiaomi M2007J20CI -- NA
# Infinix X680D -- NA
# Xiaomi M2006C3LII -- NA
# Huawei DUB-LX1 -- NA
# OPPO A37f -- NA
# Samsung SM-G770F -- NA
# Vivo Y55 1603 -- NA
# Motorola moto g(8) plus -- NA
# Infinix X682C -- NA
# Samsung SM-M017F -- NA
# Samsung SM-G975F -- NA
# Motorola Moto E6s -- NA
# Vivo 1933 -- NA
# Vivo V2022 -- NA
# Realme RMX2085 -- NA
# Samsung SM-M107F -- NA
# Samsung SM-J710FN -- NA
# Samsung SM-J330G -- NA
# Samsung SM-J510GN -- NA
# Huawei JAT-L29 -- NA
# Nokia 5.1 -- NA
# Huawei CAM-UL00 -- NA
# Nokia 7.1 -- NA
# Tecno KC1j -- NA
# Samsung SM-A730F -- NA
# HTC Desire -- 21,299
# Samsung SM-A750GN -- NA
# Motorola One Fusion+ -- NA
# Lenovo A7010a48 -- NA
# Motorola Moto E (4) Plus -- NA
# Huawei HRY-AL00 -- NA
# LG LM-G850 -- NA
# Samsung SM-G965U1 -- NA
# OPPO CPH2109 -- NA
# 10.or E -- NA
# OPPO CPH1919 -- NA
# Motorola moto e(7) plus -- NA
# Motorola moto g(6) -- NA
# Micromax Q4311 -- NA
# Oukitel K6 -- NA
# Samsung SM-A720F -- NA
# Tecno BB4k -- NA
# Realme RMX2050 -- NA
# Huawei LLD-L21 -- NA
# Huawei DUK-L09 -- NA
# Infinix X626B -- NA
# Vivo 1917 -- NA
# Samsung SM-A520F -- NA
# Micromax Q4310 -- NA
# Infinix X690 -- NA
# Nokia 6.2 -- NA
# Asus X00LD -- NA
# OPPO CPH2035 -- NA
# Tecno KE5 -- NA
# LeTV Le X509 -- NA
# Samsung SM-N960F -- NA
# LG LM-X600IM -- NA
# 10.or D -- NA
# Huawei JSN-L22 -- NA
# Huawei MHA-L29 -- NA
# Xiaomi Mi 10 -- 10,000
# Samsung SM-J530Y -- NA
# OnePlus HD1903 -- NA
# Vivo 2004 -- NA
# Samsung SM-N970F -- NA
# Lenovo Moto G (5S) -- NA
# Samsung SM-F916B -- NA
# Vivo V3Max -- NA
# Lava LE9830 -- NA
# Samsung SM-G781B -- NA
# Asus Z00LD -- NA
# Sony H4311 -- NA
# Lenovo L28111 -- NA
# Gionee MAX -- 6,399
# Tecno KE6 -- NA
# Micromax Q4204 -- NA
# LG K420 -- NA
# Lenovo ZUK Z2132 -- NA
# Infinix X655F -- NA
# Xiaomi Redmi Note 9S -- 19,090
# Xiaomi 2014818 -- NA
# Xiaomi Mi 5X -- 24,950
# Xiaomi Redmi K30 5G -- 20,190
# Samsung SM-A405FN -- NA
# Lava Z51 -- 5,299
# Samsung SM-G975U1 -- NA
# Asus Z017DB -- NA
# Vivo 1805 -- NA
# Samsung SM-G965U -- NA
# Coolpad 1825 -- NA
# Samsung SM-G955U -- NA
# X-TIGI A1 Plus -- NA
# Micromax E483 -- NA
# Huawei HRY-LX1 -- NA
# itel L6005 -- NA
# Huawei JKM-Al00A -- NA
# Lenovo PB-6505M -- NA
# OPPO CPH1907 -- NA
# Lava A97 2GB -- NA
# Huawei DUA-AL00 -- NA
# Samsung SM-G955W -- NA
# Huawei PRA-LA1 -- NA
# Huawei BND-L21 -- NA
# Motorola MotoG3 -- NA
# Lenovo P2a42 -- NA
# LG LMX130IM -- NA
# itel it1518 -- 3,998
# HTC Wildfire R70 -- 11,999
# Samsung SM-N910T -- NA
# Lava Z66 -- 8,499
# LG LG-M320 -- NA
# Tecno KC1 -- NA
# Vivo 2006 -- NA
# Tecno CD7 -- NA
# Samsung SM-G988B -- NA
# Huawei DUA-L22 -- NA
# LYF LS-5015 -- NA
# Realme RMX2081 -- NA
# Samsung SM-G9550 -- NA
# Infinix X650D -- NA
# Huawei BKK-LX2 -- NA
# Tecno LC8 -- NA
# Infinix X573 -- NA
# LYF LS-4008 -- NA
# Motorola Moto g(8) power lite -- NA
# Samsung SM-J710GN -- NA
# Huawei TRT-LX1 -- NA
# 10.or G -- NA
# Samsung SM-G970F -- NA
# Huawei FDR-A01L -- NA
# Asus X00RD -- NA
# Tecno ID3k -- NA
# Tecno KB2J -- NA
# Google Pixel 4a -- 31,999
# Xiaomi MI 8 Lite -- NA
# itel S41 -- NA
# Samsung SM-T385 -- NA
# Vivo 1851 -- NA
# Tecno KC3 -- NA
# Samsung SM-M307FN -- NA
# Nokia 4.2 -- NA
# LG LM-G910 -- NA
# Huawei RNE-L21 -- NA
# Lenovo L39051 -- NA
# Sharp X1 -- NA
# Tecno KC2j -- NA
# Samsung SM-T307U -- NA
# Huawei WAS-LX2J -- NA
# Motorola XT1650 -- NA
# LG X230 -- NA
# JHM X11 -- NA
# Tecno KB2 -- NA
# Huawei ATU-L31 -- NA
# itel L5503 -- NA
# Micromax N8301 -- NA
# LG LM-G710 -- NA
# Samsung SM-N976N -- NA
# Micromax Q402 -- NA
# Tecno KB3 -- NA
# Nokia C3 -- 4,499
# LYF LS-5201 -- NA
# Panasonic Eluga Ray 810 -- 7,499
# Micromax iOne -- 4,299
# Huawei PCT-AL10 -- NA
# Vodafone VFD 500 -- NA
# Huawei KIW-L22 -- NA
# Gionee P5W -- 6,000
# Nokia 3.1 -- NA
# ZTE NX573J -- NA
# ZTE NX569J -- NA
# Samsung SM-G9650 -- NA
# Nokia 2.1 -- NA
# Micromax N8216 -- NA
# OPPO CPH2137 -- NA
# Huawei COL-AL10 -- NA
# InFocus M680 -- 8,490
# Tecno CD8 -- NA
# Huawei FIG-LA1 -- NA
# Huawei COL-L29 -- NA
# Infinix X626 -- NA
# Lenovo TB-7504X -- NA
# Motorola MotoG3-TE -- NA
# Tecno KD7 -- NA
# Tecno KD7h -- NA
# Infinix X573B -- NA
# Tecno IN6 -- NA
# Lenovo TB-8504X -- NA
# OPPO F1f -- NA
# OPPO CPH2023 -- NA
# Samsung SM-G532F -- NA
# Tecno IA5 -- NA
# Gionee Pioneer P5L (2016) -- NA
# Gionee F10 -- 7,990
# Samsung SM-N7505 -- NA
# Samsung SM-J701M -- NA
# iVoomi Me 1+ -- NA
# Samsung SM-G975U -- NA
# Samsung SM-G970U -- NA
# Xiaomi Mi Note 10 Lite -- 28,490
# Sony F8332 -- NA
# Samsung SM-A015F -- NA
# Lenovo L19041 -- NA
# Huawei EVA-L19 -- NA
# Lenovo TB-8704X -- NA
# itel L5502 -- NA
# Coolpad 3503I Mega 3 -- NA
# Tecno KC2 -- NA
# LYF LS-5002 -- NA
# Samsung SM-P610 -- NA
# Tecno LB8a -- NA
# Infinix X650B -- NA
# Samsung SM-A750FN -- NA
# Infinix X652 -- NA
# Huawei NEM-L22 -- NA
# Huawei STF-AL00 -- NA
# Coolpad 1861 -- NA
# Sony E2363 -- NA
# Samsung GT-I9505 -- NA
# Intex Aqua Life III -- 3,699
# OPPO CPH1613 -- NA
# Intex Aqua Twist -- 5,590
# HTC Desire 828 -- NA
# LG LM-G900 -- NA
# Asus Z010D -- NA
# Coolpad 1826-I01 -- NA
# itel L6006 -- NA
# Samsung SM-T290 -- NA
# Huawei LDN-LX2 -- NA
# Vivo V1Max -- NA
# Huawei BKL-L09 -- NA
# Huawei FLA-LX1 -- NA
# itel L5503L -- NA
# Micromax YU5014 -- NA
# Tecno LC7 -- NA
# Kult Gladiator -- 4,999
# Lenovo TB3-730X -- NA
# Huawei JDN2-AL00HN -- NA
# Panasonic I7 EE -- NA
# OPPO 1201 -- NA
# Huawei AMN-LX9 -- NA
# Micromax Q4002 -- NA
# OPPO CPH2043 -- NA
# Xolo Era 5X -- 8,999
# Huawei CUN-L21 -- NA
# Gome C7 Note -- 5,390
# Lava Iris X8 L -- NA
# Micromax Q4260 -- NA
# Micromax Q452 -- NA
# Samsung SM-T295 -- NA
# Lava V2 3GB -- NA
# Samsung SM-G781V -- NA
# Tecno KE6j -- NA
# Samsung SM-N950U1 -- NA
# Asus X00LDB -- NA
# Tambo TA-3 -- 3,590
# Tecno TECNO IN1 -- NA
# Samsung SM-N9500 -- NA
# ZTE NX575J -- NA
# Micromax YU5510A -- NA
# Tecno CE7 -- NA
# OPPO CPH1879 -- NA
# OnePlus ONE A2003 -- NA
# Samsung SM-G7202 -- NA
# Micromax C2APLS -- NA
# Yuho O2 -- 7,449
# Tecno ID6 -- NA
# HTC M8e -- NA
# OnePlus KB2000 -- NA
# Samsung SM-A716B -- NA
# Samsung SM-G986U -- NA
# Xiaomi Mi 9 Lite -- NA
# Lenovo P70-A -- NA
# Infinix X652B -- NA
# Samsung SM-G530FZ -- NA
# Xolo Era 2X -- 8,099
# itel A41 Plus -- NA
# Xiaomi Mi Note 10 -- 43,290
# Infinix X682B -- NA
# OPPO CPH1875 -- NA
# Samsung SM-F907N -- NA
# Huawei HRY-LX2 -- NA
# Motorola Moto g(7) -- NA
# Sony C6903 -- NA
# Panasonic Eluga I8 -- 8,690
# Samsung SM-N935F -- NA
# Nokia 5.3 -- NA
# Samsung SM-G975W -- NA
# Motorola XT1068 -- NA
# Samsung SM-G986U1 -- NA
# Samsung SM-T825 -- NA
# itel A41 -- NA
# Samsung SM-F700F -- NA
# Huawei PIC-LX9 -- NA
# OPPO CPH1611 -- NA
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_9096\1623401018.py in <module>
#       2 for p in phones:
#       3     new_url = get_new_url(p)
# ----> 4     thepage = requests.get(new_url)
#       5     soup = BeautifulSoup(thepage.text, "html.parser")
#       6
#
# c:\Users\arnav\.conda\envs\new\lib\site-packages\requests\api.py in get(url, params, **kwargs)
#      71     """
#      72
# ---> 73     return request("get", url, params=params, **kwargs)
#      74
#      75
#
# c:\Users\arnav\.conda\envs\new\lib\site-packages\requests\api.py in request(method, url, **kwargs)
#      57     # cases, and look like a memory leak in others.
#      58     with sessions.Session() as session:
# ---> 59         return session.request(method=method, url=url, **kwargs)
#      60
#      61
#
# c:\Users\arnav\.conda\envs\new\lib\site-packages\requests\sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     585         }
#     586         send_kwargs.update(settings)
# --> 587         resp = self.send(prep, **send_kwargs)
#     588
#     589         return resp
#
# c:\Users\arnav\.conda\envs\new\lib\site-packages\requests\sessions.py in send(self, request, **kwargs)
#     699
#     700         # Send the request
# --> 701         r = adapter.send(request, **kwargs)
#     702
#     703         # Total elapsed time of the request (approximately)
#
# c:\Users\arnav\.conda\envs\new\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     497                     decode_content=False,
#     498                     retries=self.max_retries,
# --> 499                     timeout=timeout,
#     500                 )
#     501
#
# c:\Users\arnav\.conda\envs\new\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     708                 body=body,
#     709                 headers=headers,
# --> 710                 chunked=chunked,
#     711             )
#     712
#
# c:\Users\arnav\.conda\envs\new\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     384         # Trigger any extra validation we need to do.
#     385         try:
# --> 386             self._validate_conn(conn)
#     387         except (SocketTimeout, BaseSSLError) as e:
#     388             # Py2 raises this as a BaseSSLError, Py3 raises it as socket timeout.
#
# c:\Users\arnav\.conda\envs\new\lib\site-packages\urllib3\connectionpool.py in _validate_conn(self, conn)
#    1040         # Force connect early to allow us to validate the connection.
#    1041         if not getattr(conn, "sock", None):  # AppEngine might not have  `.sock`
# -> 1042             conn.connect()
#    1043
#    1044         if not conn.is_verified:
#
# c:\Users\arnav\.conda\envs\new\lib\site-packages\urllib3\connection.py in connect(self)
#     422             server_hostname=server_hostname,
#     423             ssl_context=context,
# --> 424             tls_in_tls=tls_in_tls,
#     425         )
#     426
#
# c:\Users\arnav\.conda\envs\new\lib\site-packages\urllib3\util\ssl_.py in ssl_wrap_socket(sock, keyfile, certfile, cert_reqs, ca_certs, server_hostname, ssl_version, ciphers, ssl_context, ca_cert_dir, key_password, ca_cert_data, tls_in_tls)
#     448     if send_sni:
#     449         ssl_sock = _ssl_wrap_socket_impl(
# --> 450             sock, context, tls_in_tls, server_hostname=server_hostname
#     451         )
#     452     else:
#
# c:\Users\arnav\.conda\envs\new\lib\site-packages\urllib3\util\ssl_.py in _ssl_wrap_socket_impl(sock, ssl_context, tls_in_tls, server_hostname)
#     491
#     492     if server_hostname:
# --> 493         return ssl_context.wrap_socket(sock, server_hostname=server_hostname)
#     494     else:
#     495         return ssl_context.wrap_socket(sock)
#
# c:\Users\arnav\.conda\envs\new\lib\ssl.py in wrap_socket(self, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname, session)
#     421             server_hostname=server_hostname,
#     422             context=self,
# --> 423             session=session
#     424         )
#     425
#
# c:\Users\arnav\.conda\envs\new\lib\ssl.py in _create(cls, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname, context, session)
#     868                         # non-blocking
#     869                         raise ValueError("do_handshake_on_connect should not be specified for non-blocking sockets")
# --> 870                     self.do_handshake()
#     871             except (OSError, ValueError):
#     872                 self.close()
#
# c:\Users\arnav\.conda\envs\new\lib\ssl.py in do_handshake(self, block)
#    1137             if timeout == 0.0 and block:
#    1138                 self.settimeout(None)
# -> 1139             self._sslobj.do_handshake()
#    1140         finally:
#    1141             self.settimeout(timeout)
#
# KeyboardInterrupt:
