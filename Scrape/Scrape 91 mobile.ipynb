# %%
import requests
import re
from bs4 import BeautifulSoup
from time import sleep
import urllib.parse

# %%
def get_new_url(phone):
    phone = phone.strip()
    phone=phone.lower()
    phone = phone.replace(" ", "-")
    phone = phone+"-price-in-india"
    return("https://www.91mobiles.com/" + phone)

# %%
phones = ['Samsung SM-M307F',
'Samsung SM-G780F',
'Xiaomi Redmi 8',
'Motorola Moto G (5) Plus',
'Asus X00TD',
'OnePlus AC2001',
'Realme RMX2002',
'Xiaomi Redmi Note 8',
'OPPO CPH1937',
'Huawei BKK-AL10',
'Nokia 8.1',
'Lenovo L38012',
'Xiaomi M2003J15SC',
'Samsung SM-M515F',
'Huawei LLD-AL20',
'Realme RMX2030',
'Samsung SM-N950F',
'Samsung SM-G985F',
'Vivo 1726',
'Realme RMX1971',
'OPPO CPH2127',
'Infinix X650C',
'Samsung SM-A750F',
'Samsung SM-J710F',
'Realme RMX2001',
'Samsung SM-M315F',
'Samsung SM-A217F',
'Samsung SM-A207F',
'Realme RMX2103',
'Xiaomi Redmi 8A Dual',
'Xiaomi Redmi Note 9 Pro',
'Samsung SM-J510FN',
'OPPO CPH1801',
'Xiaomi M2004J19PI',
'Xiaomi POCO X2',
'Xiaomi Redmi Note 9 Pro Max',
'Vivo V2025',
'Realme 6i',
'Nokia 2.2',
'Samsung SM-A315F',
'Xiaomi POCO M2 Pro',
'Huawei LLD-AL10',
'OnePlus HD1911',
'Motorola Moto G (5S) Plus',
'Samsung SM-F415F',
'Realme RMX2151',
'Realme RMX2189',
'Vivo V2029',
'Vivo 1820',
'Samsung SM-M215F',
'OnePlus HD1901',
'Realme RMX2027',
'Realme RMX2180',
'Vivo 1906',
'Realme RMX2170',
'Huawei STK-L22',
'Realme RMX2193',
'Samsung SM-A707F',
'Huawei BND-AL10',
'Huawei AUM-AL20',
'Samsung SM-M317F',
'OPPO CPH2015',
'Nokia 6.1',
'Vivo 1915',
'OPPO CPH2001',
'Samsung SM-M115F',
'0 0',
'Vivo 1935',
'Samsung SM-A605G',
'Nokia 2.3',
'Vivo 1909',
'Vivo 1920_20',
'Samsung SM-G955F',
'Vivo 1921',
'Huawei HRY-AL00Ta',
'Samsung SM-A715F',
'Nokia 5.1 Plus',
'Realme RMX1921',
'Huawei RNE-L22',
'Realme RMX2195',
'OPPO CPH2185',
'Samsung SM-M015G',
'Nokia 6.1 Plus',
'OPPO CPH2083',
'Samsung SM-A307FN',
'Samsung SM-G965F',
'Vivo V2027',
'Vivo 1920',
'Samsung SM-J610F',
'Realme RMX1925',
'Lenovo A7020a48',
'Vivo 1919',
'Xiaomi M2006C3LI',
'OPPO CPH2095',
'Samsung SM-A605F',
'Samsung SM-N770F',
'Vivo 1916',
'Asus X013DC',
'Motorola Moto E(4)',
'Samsung SM-A515F',
'Nokia 3.1 Plus',
'Lenovo K33a42',
'Xiaomi Redmi 8A',
'Nokia 7.2',
'Motorola Moto g(9)',
'OPPO CPH1945',
'Samsung SM-J250F',
'Samsung SM-G532G',
'Huawei INE-LX1',
'Samsung SM-A510F',
'Samsung SM-G988U1',
'Huawei COR-AL00',
'OPPO A37fw',
'Huawei JSN-L42',
'Realme RMX2161',
'Samsung SM-N975F',
'OPPO CPH2119',
'Realme RMX2185',
'Vivo 1938',
'Xiaomi M2004J19C',
'Huawei YAL-AL00',
'OPPO CPH2061',
'Nokia 3.2',
'Realme RMX1992',
'Vivo 1902',
'itel L5002',
'Xiaomi M2006C3MII',
'Samsung SM-M013F',
'Geotel A1',
'OnePlus IN2021',
'OPPO A33f',
'Realme RMX2061',
'Samsung SM-J210F',
'Infinix X655D',
'Samsung SM-P615',
'OPPO CPH1989',
'OnePlus IN2011',
'Motorola Moto One Macro',
'Lava Z61 2GB',
'Samsung SM-N980F',
'Samsung SM-G980F',
'Samsung SM-G965W',
'Realme RMX1931',
'Micromax Q402+ Bharat 2 Plus',
'Huawei STK-L21',
'Samsung SM-J415F',
'Samsung SM-J200G',
'Huawei PRA-AL00X',
'Samsung SM-A710F',
'Samsung SM-N986B',
'Samsung SM-C701F',
'OnePlus KB2001',
'Huawei MYA-L22',
'Samsung SM-A908B',
'Xiaomi M2007J20CI',
'Infinix X680D',
'Xiaomi M2006C3LII',
'Huawei DUB-LX1',
'OPPO A37f',
'Samsung SM-G770F',
'Vivo Y55 1603',
'Motorola moto g(8) plus',
'Infinix X682C',
'Samsung SM-M017F',
'Samsung SM-G975F',
'Motorola Moto E6s',
'Vivo 1933',
'Vivo V2022',
'Realme RMX2085',
'Samsung SM-M107F',
'Samsung SM-J710FN',
'Samsung SM-J330G',
'Samsung SM-J510GN',
'Huawei JAT-L29',
'Nokia 5.1',
'Huawei CAM-UL00',
'Nokia 7.1',
'Tecno KC1j',
'Samsung SM-A730F',
'HTC Desire',
'Samsung SM-A750GN',
'Motorola One Fusion+',
'Lenovo A7010a48',
'Motorola Moto E (4) Plus',
'Huawei HRY-AL00',
'LG LM-G850',
'Samsung SM-G965U1',
'OPPO CPH2109',
'10.or E',
'OPPO CPH1919',
'Motorola moto e(7) plus',
'Motorola moto g(6)',
'Micromax Q4311',
'Oukitel K6',
'Samsung SM-A720F',
'Tecno BB4k',
'Realme RMX2050',
'Huawei LLD-L21',
'Huawei DUK-L09',
'Infinix X626B',
'Vivo 1917',
'Samsung SM-A520F',
'Micromax Q4310',
'Infinix X690',
'Nokia 6.2',
'Asus X00LD',
'OPPO CPH2035',
'Tecno KE5',
'LeTV Le X509',
'Samsung SM-N960F',
'LG LM-X600IM',
'10.or D',
'Huawei JSN-L22',
'Huawei MHA-L29',
'Xiaomi Mi 10',
'Samsung SM-J530Y',
'OnePlus HD1903',
'Vivo 2004',
'Samsung SM-N970F',
'Lenovo Moto G (5S)',
'Samsung SM-F916B',
'Vivo V3Max',
'Lava LE9830',
'Samsung SM-G781B',
'Asus Z00LD',
'Sony H4311',
'Lenovo L28111',
'Gionee MAX',
'Tecno KE6',
'Micromax Q4204',
'LG K420',
'Lenovo ZUK Z2132',
'Infinix X655F',
'Xiaomi Redmi Note 9S',
'Xiaomi 2014818',
'Xiaomi Mi 5X',
'Xiaomi Redmi K30 5G',
'Samsung SM-A405FN',
'Lava Z51',
'Samsung SM-G975U1',
'Asus Z017DB',
'Vivo 1805',
'Samsung SM-G965U',
'Coolpad 1825',
'Samsung SM-G955U',
'X-TIGI A1 Plus',
'Micromax E483',
'Huawei HRY-LX1',
'itel L6005',
'Huawei JKM-Al00A',
'Lenovo PB-6505M',
'OPPO CPH1907',
'Lava A97 2GB',
'Huawei DUA-AL00',
'Samsung SM-G955W',
'Huawei PRA-LA1',
'Huawei BND-L21',
'Motorola MotoG3',
'Lenovo P2a42',
'LG LMX130IM',
'itel it1518',
'HTC Wildfire R70',
'Samsung SM-N910T',
'Lava Z66',
'LG LG-M320',
'Tecno KC1',
'Vivo 2006',
'Tecno CD7',
'Samsung SM-G988B',
'Huawei DUA-L22',
'LYF LS-5015',
'Realme RMX2081',
'Samsung SM-G9550',
'Infinix X650D',
'Huawei BKK-LX2',
'Tecno LC8',
'Infinix X573',
'LYF LS-4008',
'Motorola Moto g(8) power lite',
'Samsung SM-J710GN',
'Huawei TRT-LX1',
'10.or G',
'Samsung SM-G970F',
'Huawei FDR-A01L',
'Asus X00RD',
'Tecno ID3k',
'Tecno KB2J',
'Google Pixel 4a',
'Xiaomi MI 8 Lite',
'itel S41',
'Samsung SM-T385',
'Vivo 1851',
'Tecno KC3',
'Samsung SM-M307FN',
'Nokia 4.2',
'LG LM-G910',
'Huawei RNE-L21',
'Lenovo L39051',
'Sharp X1',
'Tecno KC2j',
'Samsung SM-T307U',
'Huawei WAS-LX2J',
'Motorola XT1650',
'LG X230',
'JHM X11',
'Tecno KB2',
'Huawei ATU-L31',
'itel L5503',
'Micromax N8301',
'LG LM-G710',
'Samsung SM-N976N',
'Micromax Q402',
'Tecno KB3',
'Nokia C3',
'LYF LS-5201',
'Panasonic Eluga Ray 810',
'Micromax iOne',
'Huawei PCT-AL10',
'Vodafone VFD 500',
'Huawei KIW-L22',
'Gionee P5W',
'Nokia 3.1',
'ZTE NX573J',
'ZTE NX569J',
'Samsung SM-G9650',
'Nokia 2.1',
'Micromax N8216',
'OPPO CPH2137',
'Huawei COL-AL10',
'InFocus M680',
'Tecno CD8',
'Huawei FIG-LA1',
'Huawei COL-L29',
'Infinix X626',
'Lenovo TB-7504X',
'Motorola MotoG3-TE',
'Tecno KD7',
'Tecno KD7h',
'Infinix X573B',
'Tecno IN6',
'Lenovo TB-8504X',
'OPPO F1f',
'OPPO CPH2023',
'Samsung SM-G532F',
'Tecno IA5',
'Gionee Pioneer P5L (2016)',
'Gionee F10',
'Samsung SM-N7505',
'Samsung SM-J701M',
'iVoomi Me 1+',
'Samsung SM-G975U',
'Samsung SM-G970U',
'Xiaomi Mi Note 10 Lite',
'Sony F8332',
'Samsung SM-A015F',
'Lenovo L19041',
'Huawei EVA-L19',
'Lenovo TB-8704X',
'itel L5502',
'Coolpad 3503I Mega 3',
'Tecno KC2',
'LYF LS-5002',
'Samsung SM-P610',
'Tecno LB8a',
'Infinix X650B',
'Samsung SM-A750FN',
'Infinix X652',
'Huawei NEM-L22',
'Huawei STF-AL00',
'Coolpad 1861',
'Sony E2363',
'Samsung GT-I9505',
'Intex Aqua Life III',
'OPPO CPH1613',
'Intex Aqua Twist',
'HTC Desire 828',
'LG LM-G900',
'Asus Z010D',
'Coolpad 1826-I01',
'itel L6006',
'Samsung SM-T290',
'Huawei LDN-LX2',
'Vivo V1Max',
'Huawei BKL-L09',
'Huawei FLA-LX1',
'itel L5503L',
'Micromax YU5014',
'Tecno LC7',
'Kult Gladiator',
'Lenovo TB3-730X',
'Huawei JDN2-AL00HN',
'Panasonic I7 EE',
'OPPO 1201',
'Huawei AMN-LX9',
'Micromax Q4002',
'OPPO CPH2043',
'Xolo Era 5X',
'Huawei CUN-L21',
'Gome C7 Note',
'Lava Iris X8 L',
'Micromax Q4260',
'Micromax Q452',
'Samsung SM-T295',
'Lava V2 3GB',
'Samsung SM-G781V',
'Tecno KE6j',
'Samsung SM-N950U1',
'Asus X00LDB',
'Tambo TA-3',
'Tecno TECNO IN1',
'Samsung SM-N9500',
'ZTE NX575J',
'Micromax YU5510A',
'Tecno CE7',
'OPPO CPH1879',
'OnePlus ONE A2003',
'Samsung SM-G7202',
'Micromax C2APLS',
'Yuho O2',
'Tecno ID6',
'HTC M8e',
'OnePlus KB2000',
'Samsung SM-A716B',
'Samsung SM-G986U',
'Xiaomi Mi 9 Lite',
'Lenovo P70-A',
'Infinix X652B',
'Samsung SM-G530FZ',
'Xolo Era 2X',
'itel A41 Plus',
'Xiaomi Mi Note 10',
'Infinix X682B',
'OPPO CPH1875',
'Samsung SM-F907N',
'Huawei HRY-LX2',
'Motorola Moto g(7)',
'Sony C6903',
'Panasonic Eluga I8',
'Samsung SM-N935F',
'Nokia 5.3',
'Samsung SM-G975W',
'Motorola XT1068',
'Samsung SM-G986U1',
'Samsung SM-T825',
'itel A41',
'Samsung SM-F700F',
'Huawei PIC-LX9',
'OPPO CPH1611',
'Tecno LB7',
'Vivo V2026',
'Huawei YAL-L21',
'Huawei POT-LX1AF',
'Lenovo A2016a40 B',
'Lava LF9810_2GB',
'Asus I001DE',
'Tecno KC8',
'Sony E5563',
'HTC M9 Plus',
'Samsung SM-T285YD',
'Micromax HS3',
'Infinix X660',
'Samsung SM-J320G',
'Samsung SM-J610G',
'Asus X00TDA',
'Lenovo TB-8505F',
'Samsung SM-G955U1',
'Samsung SM-T515',
'Intex Aqua Ring',
'Zee Z10',
'Panasonic Eluga Ray 800',
'Samsung SM-G903F',
'Vivo 1907_19',
'LG LM-G810',
'Panasonic Eluga Mark',
'BlackBerry BBE100-4',
'Motorola G8 Power',
'Samsung SM-G988U',
'Umidigi S2',
'Samsung SM-A115F',
'Micromax C1A',
'Sony Xperia Z1',
'Asus I01WD',
'Intex Aqua Young',
'Alcatel 5060A',
'Amosta 3G5',
'SonyEricsson C6602',
'InFocus IF9007',
'Samsung SM-T355Y',
'Huawei BKL-AL20',
'Samsung SM-A202F',
'Karbonn K9 Smart Selfie',
'OnePlus HD1910',
'Micromax C2A',
'Huawei AUM-AL29',
'Tecno BC2',
'Xiaomi M2006C3LG',
'Vivo I1928',
'Karbonn Frames S9',
'Nokia C2',
'Xiaomi Redmi Note 5A Prime',
'Huawei LND-L29',
'Samsung SM-G970U1',
'Huawei NXT-AL10',
'Samsung SM-T510',
'Xiaomi M2006C3MG',
'Panasonic ELUGA Ray 610',
'Kyocera E6560',
'Lava Pixel V2',
'Lenovo TB-X505X',
'LG LM-K510',
'Samsung SM-N976Q',
'Samsung SM-N970U',
'OnePlus IN2020',
'Karbonn Aura Sleek 4G',
'Xiaomi MI 9',
'Samsung SM-G9208',
'Comio C1 Pro',
'OnePlus IN2013',
'Samsung SM-J700H',
'Huawei HRY-LX1T',
'Samsung SM-T585',
'Samsung SM-J737T1',
'Huawei COR-L29',
'Lava Iris 88',
'Samsung SM-G920A',
'Motorola Moto G9 Play',
'OPPO CPH2059',
'Vivo 1940',
'Samsung SM-T815Y',
'ZTE Blade V0730',
'Coolpad 1825-I01',
'Samsung SM-G6000',
'Micromax Q413',
'Samsung SM-G9750',
'Vivo I1927',
'Coolpad 1821',
'Huawei RIO-L01',
'Lava LE9810',
'Lava A71',
'Samsung SM-N981B',
'Samsung SM-G935S',
'Samsung SM-T720',
'Samsung SM-N950U',
'Samsung SM-T505',
'Intex Aqua Strong 5.2',
'Lephone W7R',
'Lava Z61P',
'Google Nexus 5X',
'LG H872',
'Xiaomi M2002J9G',
'Xiaomi Mi MIX 2S',
'Lenovo A6600a40',
'Samsung SM-F707B',
'Lenovo TB-X605LC',
'Gionee E8',
'Samsung SM-J320A',
'Centric CM5001',
'Samsung SM-G981B',
'Samsung SM-T285',
'Sony G8342',
'Razer Phone 2',
'Motorola XT1686',
'Tecno itel-it1520',
'Micromax Q427',
'OnePlus HD1905',
'Huawei DLI-L42',
'Huawei BLL-L21',
'Samsung SM-T580',
'Lenovo TB-8505X',
'Samsung SM-G920AZ',
'Lenovo TB-X304L',
'OPPO CPH1851',
'Samsung SM-N960U',
'Samsung SM-J200F',
'HTC U11 Plus',
'Vivo X9i',
'LG LM-Q850',
'Samsung SM-N960W',
'OnePlus HD1900',
'Samsung SM-G570Y',
'Motorola XT1580',
'OnePlus E1005',
'Gionee S6',
'BlackBerry BBD100-1',
'Nokia 2.4',
'Motorola Moto E6 Play',
'Benco LE9920_P',
'M-tech Eros Smart',
'Samsung SM-T500',
'LYF LS-5501',
'Samsung SM-A5070',
'Lenovo K11 Power',
'Xiaomi Redmi Note 8T',
'Huawei DRA-LX5',
'Samsung SM-G977B',
'Samsung SM-N986U1',
'OPPO Reno4',
'Huawei CAM-L21',
'Coolpad Y83-I00',
'QMobile i6 Metal 2017',
'iBall Snap 4G2',
'OPPO CPH1951',
'Xolo Era 2X 3GB',
'Micromax Q372',
'Meizu 16th',
'Asus Z011D',
'Samsung SM-N9750',
'Huawei FIG-LX1',
'Lenovo K33 a48',
'Intex Aqua Power HD',
'HTC M9',
'Samsung SM-A426B',
'InFocus IF9031',
'Infinix X687',
'Lava P7plus',
'InFocus M260',
'Samsung SM-C9008',
'Motorola Moto G Stylus',
'Xiaomi 2014817',
'Vivo 1937',
'Mobell Tab 8',
'Micromax Q409',
'CAT S61',
'Asus X00ADC',
'Samsung SM-A217N',
'LG LM-F100',
'Huawei PCT-L29',
'LG LG-K220',
'Asus I003DD',
'itel P41',
'Micromax Q394',
'Infinix X680',
'Infinix X624',
'Lenovo YT3-X90F',
'Lava Z92',
'TP-Link Neffos C7',
'Intex Cloud Jewel',
'Samsung SM-N986U',
'OPPO Ax5s',
'Samsung SM-G955N',
'HTC U11 life',
'Ampe A77',
'LG LM-X210',
'LG LM-Q730',
'itel W6004',
'Infinix X650',
'Samsung SM-A115U1',
'Samsung SM-T805',
'Intex AQUA AMAZE+']

# %%
price = "NA"
for p in phones:
    new_url = get_new_url(p)
    thepage = requests.get(new_url)
    soup = BeautifulSoup(thepage.text, "html.parser")
    
    for div in soup.find_all('div', {'class': 'price_div'}):
        try:
            price = str(div.find('span', {'class': 'big_prc','itemprop':'price'}).getText()).strip()
        except:
            price = "NA"
        
    print(p+" -- "+price)
    price = "NA"
# Out:
# Samsung SM-M307F -- NA
# Samsung SM-G780F -- NA
# Xiaomi Redmi 8 -- 7,999
# Motorola Moto G (5) Plus -- NA
# Asus X00TD -- NA
# OnePlus AC2001 -- NA
# Realme RMX2002 -- NA
# Xiaomi Redmi Note 8 -- 12,290
# OPPO CPH1937 -- NA
# Huawei BKK-AL10 -- NA
# Nokia 8.1 -- NA
# Lenovo L38012 -- NA
# Xiaomi M2003J15SC -- NA
# Samsung SM-M515F -- NA
# Huawei LLD-AL20 -- NA
# Realme RMX2030 -- NA
# Samsung SM-N950F -- NA
# Samsung SM-G985F -- NA
# Vivo 1726 -- NA
# Realme RMX1971 -- NA
# OPPO CPH2127 -- NA
# Infinix X650C -- NA
# Samsung SM-A750F -- NA
# Samsung SM-J710F -- NA
# Realme RMX2001 -- NA
# Samsung SM-M315F -- NA
# Samsung SM-A217F -- NA
# Samsung SM-A207F -- NA
# Realme RMX2103 -- NA
# Xiaomi Redmi 8A Dual -- 7,499
# Xiaomi Redmi Note 9 Pro -- 12,994
# Samsung SM-J510FN -- NA
# OPPO CPH1801 -- NA
# Xiaomi M2004J19PI -- NA
# Xiaomi POCO X2 -- 18,999
# Xiaomi Redmi Note 9 Pro Max -- 15,789
# Vivo V2025 -- NA
# Realme 6i -- 12,949
# Nokia 2.2 -- NA
# Samsung SM-A315F -- NA
# ...
